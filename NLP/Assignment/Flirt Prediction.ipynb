# %%
import pandas as pd

# %%
df = pd.read_csv("Flirt.txt",header=None,error_bad_lines=False,encoding='utf8')
# Out:
# C:\ProgramData\anaconda3\envs\NLP\lib\site-packages\IPython\core\interactiveshell.py:3457: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)
# b'Skipping line 25: expected 2 fields, saw 6\nSkipping line 46: expected 2 fields, saw 3\n'

# %%
df
# Out:
#            0                                                  1
# 0   05/12/19   1:42 pm - Messages to this chat and calls are...
# 1   05/12/19   1:42 pm - Mabel Infoziant: Hi this is Mabel w...
# 2   05/12/19   1:42 pm - Mabel Infoziant: What’s your full name
# 3   05/12/19                      1:42 pm - AR❤: Ramisha Rani K
# 4   05/12/19                      1:42 pm - Mabel Infoziant: Ok
# 5   05/12/19   1:42 pm - Mabel Infoziant: ramisharanik@gmail...
# 6   05/12/19          1:43 pm - Mabel Infoziant: Your email Id?
# 7   18/12/19                         3:12 pm - AR❤: Missed call
# 8   18/12/19                       3:12 pm - AR❤: Media count👍🏻
# 9   05/12/19                             1:43 pm - AR❤: Yes Mam
# 10  05/12/19   1:43 pm - Mabel Infoziant: I will send 2 abst...
# 11  05/12/19                            1:43 pm - AR❤: Yeah mam
# 12  05/12/19   1:43 pm - Mabel Infoziant: Give me the list t...
# 13  05/12/19   1:43 pm - Mabel Infoziant: Send me cbe office...
# 14  05/12/19   1:44 pm - AR❤: Yeah Mam within Evening I will...
# 15  05/12/19   1:45 pm - AR❤: Tomorrow I have to visit the o...
# 16  05/12/19                      1:48 pm - Mabel Infoziant: ok
# 17  05/12/19   1:48 pm - Mabel Infoziant: send the details o...
# 18  05/12/19   1:49 pm - AR❤: Sure mam. Soon I will share de...
# 19  05/12/19   2:00 pm - AR❤: I have read the Abstract mam. ...
# 20  05/12/19   2:04 pm - Mabel Infoziant: I think Vignesh ha...
# 21  05/12/19   2:04 pm - Mabel Infoziant: I have sent the ab...
# 22  05/12/19                              2:06 pm - AR❤: Ok mam
# 23  05/12/19   2:07 pm - AR❤: I have read both the abstract ...
# 24  05/12/19   4:44 pm - Mabel Infoziant: Yes we need to ya ...
# 25  05/12/19                           4:48 pm - AR❤: Sure mam.
# 26  05/12/19                   8:07 pm - AR❤: Shall I call mam?
# 27  08/12/19   10:45 pm - Mabel Infoziant: Hi I was at churc...
# 28  08/12/19                         11:52 pm - AR❤: It's k mam
# 29  08/12/19   11:55 pm - AR❤: Just to know the tomorrow pla...
# 30  09/12/19    12:09 pm - AR❤: Mam can u send Vignesh number??
# 31  09/12/19   12:13 pm - Mabel Infoziant: Vignesh ML Infozi...
# 32  09/12/19   12:23 pm - Mabel Infoziant: I was in a meetin...
# 33  09/12/19                    12:25 pm - AR❤: Can I cal u mam
# 34  09/12/19   12:26 pm - AR❤: Waiting for u r finalization ...
# 35  09/12/19   12:26 pm - AR❤: If we finiliaze I can work wi...
# 36  09/12/19   12:28 pm - AR❤: So what ever may be ..if you ...
# 37  09/12/19           12:28 pm - AR❤: You deleted this message
# 38  09/12/19                     12:29 pm - AR❤: Do the needful
# 39  09/12/19   12:41 pm - Mabel Infoziant: No ma please hold...
# 40  09/12/19                     12:42 pm - AR❤: Ok mam thank u
# 41  10/12/19   7:59 am - Mabel Infoziant: Ramisha we need to...
# 42  10/12/19   8:00 am - Mabel Infoziant: Be ready to discus...
# 43  10/12/19                            8:55 am - AR❤: Okay mam
# 44  12/12/19                      2:26 pm - Mabel Infoziant: ok
# 45  15/12/19                     8:22 pm - AR❤: Mam are u free?
# 46  15/12/19   8:40 pm - Mabel Infoziant: Am at church can c...
# 47  15/12/19   8:40 pm - AR❤: Kk mam. I will ask Arun brothe...
# 48  18/12/19                              3:09 pm - AR❤: Hi mam
# 49  18/12/19                    3:09 pm - AR❤: Any updates mam?
# 50  18/12/19   3:11 pm - Mabel Infoziant: U might have to st...
# 51  18/12/19   3:11 pm - Mabel Infoziant: There is one proje...
# 52  18/12/19                            3:12 pm - AR❤: Kk mam👍🏻

# %%
df = df.drop(0)

# %%
df.columns=['Most Active Day','Chat']
Message=df["Chat"].str.split("-",n=1,expand=True)
df["Most Active Time"]=Message[0]
Message1=Message[1].str.split(":",n=1,expand=True)
df["Name"]=Message1[0]
df["Chat"]=Message1[1]
df=df[["Most Active Day","Most Active Time","Name","Chat"]]
df
# Out:
#    Most Active Day Most Active Time              Name  \
# 1         05/12/19         1:42 pm    Mabel Infoziant
# 2         05/12/19         1:42 pm    Mabel Infoziant
# 3         05/12/19         1:42 pm                AR❤
# 4         05/12/19         1:42 pm    Mabel Infoziant
# 5         05/12/19         1:42 pm    Mabel Infoziant
# 6         05/12/19         1:43 pm    Mabel Infoziant
# 7         18/12/19         3:12 pm                AR❤
# 8         18/12/19         3:12 pm                AR❤
# 9         05/12/19         1:43 pm                AR❤
# 10        05/12/19         1:43 pm    Mabel Infoziant
# 11        05/12/19         1:43 pm                AR❤
# 12        05/12/19         1:43 pm    Mabel Infoziant
# 13        05/12/19         1:43 pm    Mabel Infoziant
# 14        05/12/19         1:44 pm                AR❤
# 15        05/12/19         1:45 pm                AR❤
# 16        05/12/19         1:48 pm    Mabel Infoziant
# 17        05/12/19         1:48 pm    Mabel Infoziant
# 18        05/12/19         1:49 pm                AR❤
# 19        05/12/19         2:00 pm                AR❤
# 20        05/12/19         2:04 pm    Mabel Infoziant
# 21        05/12/19         2:04 pm    Mabel Infoziant
# 22        05/12/19         2:06 pm                AR❤
# 23        05/12/19         2:07 pm                AR❤
# 24        05/12/19         4:44 pm    Mabel Infoziant
# 25        05/12/19         4:48 pm                AR❤
# 26        05/12/19         8:07 pm                AR❤
# 27        08/12/19        10:45 pm    Mabel Infoziant
# 28        08/12/19        11:52 pm                AR❤
# 29        08/12/19        11:55 pm                AR❤
# 30        09/12/19        12:09 pm                AR❤
# 31        09/12/19        12:13 pm    Mabel Infoziant
# 32        09/12/19        12:23 pm    Mabel Infoziant
# 33        09/12/19        12:25 pm                AR❤
# 34        09/12/19        12:26 pm                AR❤
# 35        09/12/19        12:26 pm                AR❤
# 36        09/12/19        12:28 pm                AR❤
# 37        09/12/19        12:28 pm                AR❤
# 38        09/12/19        12:29 pm                AR❤
# 39        09/12/19        12:41 pm    Mabel Infoziant
# 40        09/12/19        12:42 pm                AR❤
# 41        10/12/19         7:59 am    Mabel Infoziant
# 42        10/12/19         8:00 am    Mabel Infoziant
# 43        10/12/19         8:55 am                AR❤
# 44        12/12/19         2:26 pm    Mabel Infoziant
# 45        15/12/19         8:22 pm                AR❤
# 46        15/12/19         8:40 pm    Mabel Infoziant
# 47        15/12/19         8:40 pm                AR❤
# 48        18/12/19         3:09 pm                AR❤
# 49        18/12/19         3:09 pm                AR❤
# 50        18/12/19         3:11 pm    Mabel Infoziant
# 51        18/12/19         3:11 pm    Mabel Infoziant
# 52        18/12/19         3:12 pm                AR❤
#
#                                                  Chat
# 1                      Hi this is Mabel we just spoke
# 2                               What’s your full name
# 3                                      Ramisha Rani K
# 4                                                  Ok
# 5                              ramisharanik@gmail.com
# 6                                      Your email Id?
# 7                                         Missed call
# 8                                       Media count👍🏻
# 9                                             Yes Mam
# 10     I will send 2 abstracts for u to start working
# 11                                           Yeah mam
# 12                   Give me the list that u have too
# 13   Send me cbe office address and phone number I...
# 14    Yeah Mam within Evening I will forward you mam.
# 15   Tomorrow I have to visit the office.yet not I...
# 16                                                 ok
# 17   send the details of office location once u ge...
# 18   Sure mam. Soon I will share details with you mam
# 19   I have read the Abstract mam. We can do mam. ...
# 20   I think Vignesh has the data set will ask him...
# 21                          I have sent the abstracts
# 22                                             Ok mam
# 23   I have read both the abstract mam. We can do ...
# 24   Yes we need to ya about amount and all other ...
# 25                                          Sure mam.
# 26                                  Shall I call mam?
# 27         Hi I was at church couldn’t take your call
# 28                                         It's k mam
# 29   Just to know the tomorrow plan mam.will see t...
# 30                    Mam can u send Vignesh number??
# 31           Vignesh ML Infoziant.vcf (file attached)
# 32                           I was in a meeting sorry
# 33                                    Can I cal u mam
# 34   Waiting for u r finalization of rates for our...
# 35   If we finiliaze I can work with full involvem...
# 36   So what ever may be ..if you think your are c...
# 37                           You deleted this message
# 38                                     Do the needful
# 39   No ma please hold I am in a hot meeting with ...
# 40                                     Ok mam thank u
# 41   Ramisha we need to talk today i will call u a...
# 42     Be ready to discuss about the ML titles u have
# 43                                           Okay mam
# 44                                                 ok
# 45                                    Mam are u free?
# 46   Am at church can call very late or tomorrow only
# 47   Kk mam. I will ask Arun brother. Small doubt ...
# 48                                             Hi mam
# 49                                   Any updates mam?
# 50     U might have to start on the WhatsApp analysis
# 51            There is one project that got committed
# 52                                           Kk mam👍🏻

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 52 entries, 1 to 52
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Most Active Day   52 non-null     object
#  1   Most Active Time  52 non-null     object
#  2   Name              52 non-null     object
#  3   Chat              52 non-null     object
# dtypes: object(4)
# memory usage: 2.0+ KB

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
dataset=df

# %%
dataset.dropna(inplace=True)

# %%
sid = SentimentIntensityAnalyzer()

# %%
senti=sid.polarity_scores(dataset['Chat'][31])

# %%
senti
# Out:
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}

# %%
 def sentimentalAnalysis(data,columnname):
        
        #downloading vader_lexicon for the process
        import matplotlib.pyplot as plt
        import seaborn as sns
        "Importing Necessary Packeage"
        from nltk.sentiment.vader import SentimentIntensityAnalyzer
        sid = SentimentIntensityAnalyzer()
        
        "Deleting null pr empty value"
        data.dropna(inplace=True)
        
        "Checking for a comment"
        #sid.polarity_scores(data[columnname][93])
        
        "Creating respective columns"
        
        data['scores'] = data[columnname].apply(lambda commentText: sid.polarity_scores(commentText))
        data['compound']  = data['scores'].apply(lambda score_dict: score_dict['compound'])
        data['Negtive']  = data['scores'].apply(lambda score_dict: score_dict['neg'])
        data['Postive']  = data['scores'].apply(lambda score_dict: score_dict['pos'])
        data['Neutral']  = data['scores'].apply(lambda score_dict: score_dict['neu'])
        message_counts = data['Name'].value_counts()
        median_count = message_counts.median()

        "Creating final pos or neg using compound score"
        data['comp_score'] = data['compound'].apply(lambda c: 'Flirt' if c >=0 else 'Not-Flirt')
        data['talkative_score'] = data['Name'].apply(
    lambda name: 'Talkative' if message_counts[name] >= median_count else 'Less-Talkative'
)
        plt.clf()
        #comp=sns.countplot(x = 'comp_score', hue = 'Name', data = data, palette = 'magma')
        #comp.figure.savefig("date_charts.png")
        "Checking how many pos and neg"
        posneg=pd.DataFrame(data['comp_score'].value_counts())
        return posneg,data

# %%
pos,data_Senti=sentimentalAnalysis(dataset,columnname='Chat')

# %%
data_Senti
# Out:
#    Most Active Day Most Active Time              Name  \
# 1         05/12/19         1:42 pm    Mabel Infoziant
# 2         05/12/19         1:42 pm    Mabel Infoziant
# 3         05/12/19         1:42 pm                AR❤
# 4         05/12/19         1:42 pm    Mabel Infoziant
# 5         05/12/19         1:42 pm    Mabel Infoziant
# 6         05/12/19         1:43 pm    Mabel Infoziant
# 7         18/12/19         3:12 pm                AR❤
# 8         18/12/19         3:12 pm                AR❤
# 9         05/12/19         1:43 pm                AR❤
# 10        05/12/19         1:43 pm    Mabel Infoziant
# 11        05/12/19         1:43 pm                AR❤
# 12        05/12/19         1:43 pm    Mabel Infoziant
# 13        05/12/19         1:43 pm    Mabel Infoziant
# 14        05/12/19         1:44 pm                AR❤
# 15        05/12/19         1:45 pm                AR❤
# 16        05/12/19         1:48 pm    Mabel Infoziant
# 17        05/12/19         1:48 pm    Mabel Infoziant
# 18        05/12/19         1:49 pm                AR❤
# 19        05/12/19         2:00 pm                AR❤
# 20        05/12/19         2:04 pm    Mabel Infoziant
# 21        05/12/19         2:04 pm    Mabel Infoziant
# 22        05/12/19         2:06 pm                AR❤
# 23        05/12/19         2:07 pm                AR❤
# 24        05/12/19         4:44 pm    Mabel Infoziant
# 25        05/12/19         4:48 pm                AR❤
# 26        05/12/19         8:07 pm                AR❤
# 27        08/12/19        10:45 pm    Mabel Infoziant
# 28        08/12/19        11:52 pm                AR❤
# 29        08/12/19        11:55 pm                AR❤
# 30        09/12/19        12:09 pm                AR❤
# 31        09/12/19        12:13 pm    Mabel Infoziant
# 32        09/12/19        12:23 pm    Mabel Infoziant
# 33        09/12/19        12:25 pm                AR❤
# 34        09/12/19        12:26 pm                AR❤
# 35        09/12/19        12:26 pm                AR❤
# 36        09/12/19        12:28 pm                AR❤
# 37        09/12/19        12:28 pm                AR❤
# 38        09/12/19        12:29 pm                AR❤
# 39        09/12/19        12:41 pm    Mabel Infoziant
# 40        09/12/19        12:42 pm                AR❤
# 41        10/12/19         7:59 am    Mabel Infoziant
# 42        10/12/19         8:00 am    Mabel Infoziant
# 43        10/12/19         8:55 am                AR❤
# 44        12/12/19         2:26 pm    Mabel Infoziant
# 45        15/12/19         8:22 pm                AR❤
# 46        15/12/19         8:40 pm    Mabel Infoziant
# 47        15/12/19         8:40 pm                AR❤
# 48        18/12/19         3:09 pm                AR❤
# 49        18/12/19         3:09 pm                AR❤
# 50        18/12/19         3:11 pm    Mabel Infoziant
# 51        18/12/19         3:11 pm    Mabel Infoziant
# 52        18/12/19         3:12 pm                AR❤
#
#                                                  Chat  \
# 1                      Hi this is Mabel we just spoke
# 2                               What’s your full name
# 3                                      Ramisha Rani K
# 4                                                  Ok
# 5                              ramisharanik@gmail.com
# 6                                      Your email Id?
# 7                                         Missed call
# 8                                       Media count👍🏻
# 9                                             Yes Mam
# 10     I will send 2 abstracts for u to start working
# 11                                           Yeah mam
# 12                   Give me the list that u have too
# 13   Send me cbe office address and phone number I...
# 14    Yeah Mam within Evening I will forward you mam.
# 15   Tomorrow I have to visit the office.yet not I...
# 16                                                 ok
# 17   send the details of office location once u ge...
# 18   Sure mam. Soon I will share details with you mam
# 19   I have read the Abstract mam. We can do mam. ...
# 20   I think Vignesh has the data set will ask him...
# 21                          I have sent the abstracts
# 22                                             Ok mam
# 23   I have read both the abstract mam. We can do ...
# 24   Yes we need to ya about amount and all other ...
# 25                                          Sure mam.
# 26                                  Shall I call mam?
# 27         Hi I was at church couldn’t take your call
# 28                                         It's k mam
# 29   Just to know the tomorrow plan mam.will see t...
# 30                    Mam can u send Vignesh number??
# 31           Vignesh ML Infoziant.vcf (file attached)
# 32                           I was in a meeting sorry
# 33                                    Can I cal u mam
# 34   Waiting for u r finalization of rates for our...
# 35   If we finiliaze I can work with full involvem...
# 36   So what ever may be ..if you think your are c...
# 37                           You deleted this message
# 38                                     Do the needful
# 39   No ma please hold I am in a hot meeting with ...
# 40                                     Ok mam thank u
# 41   Ramisha we need to talk today i will call u a...
# 42     Be ready to discuss about the ML titles u have
# 43                                           Okay mam
# 44                                                 ok
# 45                                    Mam are u free?
# 46   Am at church can call very late or tomorrow only
# 47   Kk mam. I will ask Arun brother. Small doubt ...
# 48                                             Hi mam
# 49                                   Any updates mam?
# 50     U might have to start on the WhatsApp analysis
# 51            There is one project that got committed
# 52                                           Kk mam👍🏻
#
#                                                scores  compound  Negtive  \
# 1   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 2   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 3   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 4   {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound...    0.2960    0.000
# 5   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 6   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 7   {'neg': 0.688, 'neu': 0.312, 'pos': 0.0, 'comp...   -0.2960    0.688
# 8   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 9   {'neg': 0.0, 'neu': 0.27, 'pos': 0.73, 'compou...    0.4019    0.000
# 10  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 11  {'neg': 0.0, 'neu': 0.312, 'pos': 0.688, 'comp...    0.2960    0.000
# 12  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 13  {'neg': 0.0, 'neu': 0.915, 'pos': 0.085, 'comp...    0.0772    0.000
# 14  {'neg': 0.0, 'neu': 0.761, 'pos': 0.239, 'comp...    0.2960    0.000
# 15  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 16  {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound...    0.2960    0.000
# 17  {'neg': 0.0, 'neu': 0.896, 'pos': 0.104, 'comp...    0.3612    0.000
# 18  {'neg': 0.0, 'neu': 0.609, 'pos': 0.391, 'comp...    0.5423    0.000
# 19  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 20  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 21  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 22  {'neg': 0.0, 'neu': 0.312, 'pos': 0.688, 'comp...    0.2960    0.000
# 23  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 24  {'neg': 0.0, 'neu': 0.838, 'pos': 0.162, 'comp...    0.4019    0.000
# 25  {'neg': 0.0, 'neu': 0.303, 'pos': 0.697, 'comp...    0.3182    0.000
# 26  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 27  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 28  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 29  {'neg': 0.0, 'neu': 0.775, 'pos': 0.225, 'comp...    0.4404    0.000
# 30  {'neg': 0.0, 'neu': 0.707, 'pos': 0.293, 'comp...    0.1680    0.000
# 31  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 32  {'neg': 0.302, 'neu': 0.698, 'pos': 0.0, 'comp...   -0.0772    0.302
# 33  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 34  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 35  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 36  {'neg': 0.0, 'neu': 0.875, 'pos': 0.125, 'comp...    0.5106    0.000
# 37  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 38  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 39  {'neg': 0.174, 'neu': 0.736, 'pos': 0.089, 'co...   -0.2960    0.174
# 40  {'neg': 0.0, 'neu': 0.175, 'pos': 0.825, 'comp...    0.5719    0.000
# 41  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 42  {'neg': 0.0, 'neu': 0.762, 'pos': 0.238, 'comp...    0.3612    0.000
# 43  {'neg': 0.0, 'neu': 0.345, 'pos': 0.655, 'comp...    0.2263    0.000
# 44  {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound...    0.2960    0.000
# 45  {'neg': 0.0, 'neu': 0.377, 'pos': 0.623, 'comp...    0.5106    0.000
# 46  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 47  {'neg': 0.111, 'neu': 0.619, 'pos': 0.27, 'com...    0.5574    0.111
# 48  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 49  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 50  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 51  {'neg': 0.0, 'neu': 0.741, 'pos': 0.259, 'comp...    0.2732    0.000
# 52  {'neg': 0.0, 'neu': 0.286, 'pos': 0.714, 'comp...    0.3612    0.000
#
#     Postive  Neutral comp_score talkative_score
# 1     0.000    1.000      Flirt  Less-Talkative
# 2     0.000    1.000      Flirt  Less-Talkative
# 3     0.000    1.000      Flirt       Talkative
# 4     1.000    0.000      Flirt  Less-Talkative
# 5     0.000    1.000      Flirt  Less-Talkative
# 6     0.000    1.000      Flirt  Less-Talkative
# 7     0.000    0.312  Not-Flirt       Talkative
# 8     0.000    1.000      Flirt       Talkative
# 9     0.730    0.270      Flirt       Talkative
# 10    0.000    1.000      Flirt  Less-Talkative
# 11    0.688    0.312      Flirt       Talkative
# 12    0.000    1.000      Flirt  Less-Talkative
# 13    0.085    0.915      Flirt  Less-Talkative
# 14    0.239    0.761      Flirt       Talkative
# 15    0.000    1.000      Flirt       Talkative
# 16    1.000    0.000      Flirt  Less-Talkative
# 17    0.104    0.896      Flirt  Less-Talkative
# 18    0.391    0.609      Flirt       Talkative
# 19    0.000    1.000      Flirt       Talkative
# 20    0.000    1.000      Flirt  Less-Talkative
# 21    0.000    1.000      Flirt  Less-Talkative
# 22    0.688    0.312      Flirt       Talkative
# 23    0.000    1.000      Flirt       Talkative
# 24    0.162    0.838      Flirt  Less-Talkative
# 25    0.697    0.303      Flirt       Talkative
# 26    0.000    1.000      Flirt       Talkative
# 27    0.000    1.000      Flirt  Less-Talkative
# 28    0.000    1.000      Flirt       Talkative
# 29    0.225    0.775      Flirt       Talkative
# 30    0.293    0.707      Flirt       Talkative
# 31    0.000    1.000      Flirt  Less-Talkative
# 32    0.000    0.698  Not-Flirt  Less-Talkative
# 33    0.000    1.000      Flirt       Talkative
# 34    0.000    1.000      Flirt       Talkative
# 35    0.000    1.000      Flirt       Talkative
# 36    0.125    0.875      Flirt       Talkative
# 37    0.000    1.000      Flirt       Talkative
# 38    0.000    1.000      Flirt       Talkative
# 39    0.089    0.736  Not-Flirt  Less-Talkative
# 40    0.825    0.175      Flirt       Talkative
# 41    0.000    1.000      Flirt  Less-Talkative
# 42    0.238    0.762      Flirt  Less-Talkative
# 43    0.655    0.345      Flirt       Talkative
# 44    1.000    0.000      Flirt  Less-Talkative
# 45    0.623    0.377      Flirt       Talkative
# 46    0.000    1.000      Flirt  Less-Talkative
# 47    0.270    0.619      Flirt       Talkative
# 48    0.000    1.000      Flirt       Talkative
# 49    0.000    1.000      Flirt       Talkative
# 50    0.000    1.000      Flirt  Less-Talkative
# 51    0.259    0.741      Flirt  Less-Talkative
# 52    0.714    0.286      Flirt       Talkative

# %%
pos

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf=TfidfVectorizer(max_df=0.95,min_df=2,stop_words='english')
dtm=tfidf.fit_transform(df["Chat"])

# %%
from sklearn.decomposition import NMF
nmf_model=NMF(n_components=5,random_state=42)
nmf_model.fit(dtm)
# Out:
# C:\ProgramData\anaconda3\envs\NLP\lib\site-packages\sklearn\decomposition\_nmf.py:294: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   FutureWarning,
# NMF(n_components=5, random_state=42)

# %%
for index,topic in enumerate(nmf_model.components_):
    results=([tfidf.get_feature_names()[i] for i in topic.argsort()[-10:]])
    print(results)
# Out:
# ['share', 'soon', 'ask', 'yes', 'sure', 'read', 'abstract', 'kk', 'yeah', 'mam']
# ['hi', 'kk', 'know', 'meeting', 'yes', 'just', 'send', 'tomorrow', 'mam', 'ok']
# ['details', 'abstracts', 'start', 'students', 'phone', 'ask', 'office', 'number', 'vignesh', 'send']
# ['ask', 'abstracts', 'number', 'mam', 'office', 'know', 'just', 'tomorrow', 'church', 'hi']
# ['students', 'know', 'sure', 'share', 'soon', 'meeting', 'details', 'yes', 'need', 'ramisha']
# C:\ProgramData\anaconda3\envs\NLP\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
topic_results=nmf_model.transform(dtm)
df["Topic"]=topic_results.argmax(axis=1)

# %%
df
# Out:
#    Most Active Day Most Active Time              Name  \
# 1         05/12/19         1:42 pm    Mabel Infoziant
# 2         05/12/19         1:42 pm    Mabel Infoziant
# 3         05/12/19         1:42 pm                AR❤
# 4         05/12/19         1:42 pm    Mabel Infoziant
# 5         05/12/19         1:42 pm    Mabel Infoziant
# 6         05/12/19         1:43 pm    Mabel Infoziant
# 7         05/12/19         1:43 pm                AR❤
# 8         05/12/19         1:43 pm    Mabel Infoziant
# 9         05/12/19         1:43 pm                AR❤
# 10        05/12/19         1:43 pm    Mabel Infoziant
# 11        05/12/19         1:43 pm    Mabel Infoziant
# 12        05/12/19         1:44 pm                AR❤
# 13        05/12/19         1:45 pm                AR❤
# 14        05/12/19         1:48 pm    Mabel Infoziant
# 15        05/12/19         1:48 pm    Mabel Infoziant
# 16        05/12/19         1:49 pm                AR❤
# 17        05/12/19         2:00 pm                AR❤
# 18        05/12/19         2:04 pm    Mabel Infoziant
# 19        05/12/19         2:04 pm    Mabel Infoziant
# 20        05/12/19         2:06 pm                AR❤
# 21        05/12/19         2:07 pm                AR❤
# 22        05/12/19         4:44 pm    Mabel Infoziant
# 23        05/12/19         4:48 pm                AR❤
# 24        05/12/19         8:07 pm                AR❤
# 25        08/12/19        10:45 pm    Mabel Infoziant
# 26        08/12/19        11:52 pm                AR❤
# 27        08/12/19        11:55 pm                AR❤
# 28        09/12/19        12:09 pm                AR❤
# 29        09/12/19        12:13 pm    Mabel Infoziant
# 30        09/12/19        12:23 pm    Mabel Infoziant
# 31        09/12/19        12:25 pm                AR❤
# 32        09/12/19        12:26 pm                AR❤
# 33        09/12/19        12:26 pm                AR❤
# 34        09/12/19        12:28 pm                AR❤
# 35        09/12/19        12:28 pm                AR❤
# 36        09/12/19        12:29 pm                AR❤
# 37        09/12/19        12:41 pm    Mabel Infoziant
# 38        09/12/19        12:42 pm                AR❤
# 39        10/12/19         7:59 am    Mabel Infoziant
# 40        10/12/19         8:00 am    Mabel Infoziant
# 41        10/12/19         8:55 am                AR❤
# 42        12/12/19         2:26 pm    Mabel Infoziant
# 43        15/12/19         8:22 pm                AR❤
# 44        15/12/19         8:40 pm    Mabel Infoziant
# 45        15/12/19         8:40 pm                AR❤
# 46        18/12/19         3:09 pm                AR❤
# 47        18/12/19         3:09 pm                AR❤
# 48        18/12/19         3:11 pm    Mabel Infoziant
# 49        18/12/19         3:11 pm    Mabel Infoziant
# 50        18/12/19         3:12 pm                AR❤
#
#                                                  Chat  \
# 1                      Hi this is Mabel we just spoke
# 2                               What’s your full name
# 3                                      Ramisha Rani K
# 4                                                  Ok
# 5                              ramisharanik@gmail.com
# 6                                      Your email Id?
# 7                                             Yes Mam
# 8      I will send 2 abstracts for u to start working
# 9                                            Yeah mam
# 10                   Give me the list that u have too
# 11   Send me cbe office address and phone number I...
# 12    Yeah Mam within Evening I will forward you mam.
# 13   Tomorrow I have to visit the office.yet not I...
# 14                                                 ok
# 15   send the details of office location once u ge...
# 16   Sure mam. Soon I will share details with you mam
# 17   I have read the Abstract mam. We can do mam. ...
# 18   I think Vignesh has the data set will ask him...
# 19                          I have sent the abstracts
# 20                                             Ok mam
# 21   I have read both the abstract mam. We can do ...
# 22   Yes we need to ya about amount and all other ...
# 23                                          Sure mam.
# 24                                  Shall I call mam?
# 25         Hi I was at church couldn’t take your call
# 26                                         It's k mam
# 27   Just to know the tomorrow plan mam.will see t...
# 28                    Mam can u send Vignesh number??
# 29           Vignesh ML Infoziant.vcf (file attached)
# 30                           I was in a meeting sorry
# 31                                    Can I cal u mam
# 32   Waiting for u r finalization of rates for our...
# 33   If we finiliaze I can work with full involvem...
# 34   So what ever may be ..if you think your are c...
# 35                           You deleted this message
# 36                                     Do the needful
# 37   No ma please hold I am in a hot meeting with ...
# 38                                     Ok mam thank u
# 39   Ramisha we need to talk today i will call u a...
# 40     Be ready to discuss about the ML titles u have
# 41                                           Okay mam
# 42                                                 ok
# 43                                    Mam are u free?
# 44   Am at church can call very late or tomorrow only
# 45   Kk mam. I will ask Arun brother. Small doubt ...
# 46                                             Hi mam
# 47                                   Any updates mam?
# 48     U might have to start on the WhatsApp analysis
# 49            There is one project that got committed
# 50                                           Kk mam👍🏻
#
#                                                scores  compound  Negtive  \
# 1   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 2   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 3   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 4   {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound...    0.2960    0.000
# 5   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 6   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 7   {'neg': 0.0, 'neu': 0.27, 'pos': 0.73, 'compou...    0.4019    0.000
# 8   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 9   {'neg': 0.0, 'neu': 0.312, 'pos': 0.688, 'comp...    0.2960    0.000
# 10  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 11  {'neg': 0.0, 'neu': 0.915, 'pos': 0.085, 'comp...    0.0772    0.000
# 12  {'neg': 0.0, 'neu': 0.761, 'pos': 0.239, 'comp...    0.2960    0.000
# 13  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 14  {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound...    0.2960    0.000
# 15  {'neg': 0.0, 'neu': 0.896, 'pos': 0.104, 'comp...    0.3612    0.000
# 16  {'neg': 0.0, 'neu': 0.609, 'pos': 0.391, 'comp...    0.5423    0.000
# 17  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 18  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 19  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 20  {'neg': 0.0, 'neu': 0.312, 'pos': 0.688, 'comp...    0.2960    0.000
# 21  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 22  {'neg': 0.0, 'neu': 0.838, 'pos': 0.162, 'comp...    0.4019    0.000
# 23  {'neg': 0.0, 'neu': 0.303, 'pos': 0.697, 'comp...    0.3182    0.000
# 24  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 25  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 26  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 27  {'neg': 0.0, 'neu': 0.775, 'pos': 0.225, 'comp...    0.4404    0.000
# 28  {'neg': 0.0, 'neu': 0.707, 'pos': 0.293, 'comp...    0.1680    0.000
# 29  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 30  {'neg': 0.302, 'neu': 0.698, 'pos': 0.0, 'comp...   -0.0772    0.302
# 31  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 32  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 33  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 34  {'neg': 0.0, 'neu': 0.875, 'pos': 0.125, 'comp...    0.5106    0.000
# 35  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 36  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 37  {'neg': 0.174, 'neu': 0.736, 'pos': 0.089, 'co...   -0.2960    0.174
# 38  {'neg': 0.0, 'neu': 0.175, 'pos': 0.825, 'comp...    0.5719    0.000
# 39  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 40  {'neg': 0.0, 'neu': 0.762, 'pos': 0.238, 'comp...    0.3612    0.000
# 41  {'neg': 0.0, 'neu': 0.345, 'pos': 0.655, 'comp...    0.2263    0.000
# 42  {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound...    0.2960    0.000
# 43  {'neg': 0.0, 'neu': 0.377, 'pos': 0.623, 'comp...    0.5106    0.000
# 44  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 45  {'neg': 0.111, 'neu': 0.619, 'pos': 0.27, 'com...    0.5574    0.111
# 46  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 47  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 48  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 49  {'neg': 0.0, 'neu': 0.741, 'pos': 0.259, 'comp...    0.2732    0.000
# 50  {'neg': 0.0, 'neu': 0.286, 'pos': 0.714, 'comp...    0.3612    0.000
#
#     Postive  Neutral comp_score  Topic
# 1     0.000    1.000      Flirt      3
# 2     0.000    1.000      Flirt      0
# 3     0.000    1.000      Flirt      4
# 4     1.000    0.000      Flirt      1
# 5     0.000    1.000      Flirt      0
# 6     0.000    1.000      Flirt      0
# 7     0.730    0.270      Flirt      4
# 8     0.000    1.000      Flirt      2
# 9     0.688    0.312      Flirt      0
# 10    0.000    1.000      Flirt      0
# 11    0.085    0.915      Flirt      2
# 12    0.239    0.761      Flirt      0
# 13    0.000    1.000      Flirt      2
# 14    1.000    0.000      Flirt      1
# 15    0.104    0.896      Flirt      2
# 16    0.391    0.609      Flirt      0
# 17    0.000    1.000      Flirt      0
# 18    0.000    1.000      Flirt      2
# 19    0.000    1.000      Flirt      2
# 20    0.688    0.312      Flirt      1
# 21    0.000    1.000      Flirt      0
# 22    0.162    0.838      Flirt      4
# 23    0.697    0.303      Flirt      0
# 24    0.000    1.000      Flirt      0
# 25    0.000    1.000      Flirt      3
# 26    0.000    1.000      Flirt      0
# 27    0.225    0.775      Flirt      3
# 28    0.293    0.707      Flirt      2
# 29    0.000    1.000      Flirt      2
# 30    0.000    0.698  Not-Flirt      4
# 31    0.000    1.000      Flirt      0
# 32    0.000    1.000      Flirt      0
# 33    0.000    1.000      Flirt      2
# 34    0.125    0.875      Flirt      0
# 35    0.000    1.000      Flirt      0
# 36    0.000    1.000      Flirt      0
# 37    0.089    0.736  Not-Flirt      4
# 38    0.825    0.175      Flirt      1
# 39    0.000    1.000      Flirt      4
# 40    0.238    0.762      Flirt      2
# 41    0.655    0.345      Flirt      0
# 42    1.000    0.000      Flirt      1
# 43    0.623    0.377      Flirt      0
# 44    0.000    1.000      Flirt      3
# 45    0.270    0.619      Flirt      0
# 46    0.000    1.000      Flirt      3
# 47    0.000    1.000      Flirt      0
# 48    0.000    1.000      Flirt      2
# 49    0.259    0.741      Flirt      2
# 50    0.714    0.286      Flirt      0

# %%
df["Topic"].value_counts()
# Out:
# 0    22
# 2    12
# 4     6
# 3     5
# 1     5
# Name: Topic, dtype: int64
